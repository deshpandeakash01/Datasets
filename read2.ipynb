# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"D:\Datasets\GLOF-zone-1\data\HMAGLOFDB v1.0_30122022.csv",encoding='latin1')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 697 entries, 0 to 696
# Data columns (total 59 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   GF_ID                   697 non-null    int64
#  1   Year_approx             549 non-null    object
#  2   Year_exact              516 non-null    float64
#  3   Month                   325 non-null    float64
#  4   Day                     275 non-null    float64
#  5   Lake_name               696 non-null    object
#  6   Glacier_name            695 non-null    object
#  7   GL_ID                   694 non-null    object
#  8   LakeDB_ID               362 non-null    object
#  9   G_ID                    693 non-null    object
#  10  Lat_lake                697 non-null    float64
#  11  Lon_lake                697 non-null    float64
#  12  Elev_lake               690 non-null    float64
#  13  Lat_impact              459 non-null    float64
# ...

# %%
data.sample(5)
# Out:
#      GF_ID Year_approx  Year_exact  Month   Day   Lake_name  \
# 131    320        1985      1985.0    8.0   9.0  Merzbacher
# 512    224        1971      1971.0    8.0   2.0      Kyagar
# 325    394        2002      2002.0    8.0   7.0    Shahdara
# 610    623         NaN         NaN    NaN   NaN     Unnamed
# 48     491        2017      2017.0    4.0  20.0   Langmale
#
#           Glacier_name            GL_ID LakeDB_ID            G_ID  ...  \
# 131  Southern Inylshek  GL079841E42200N         2  G080193E42063N  ...
# 512             Kyagar  GL077181E35675N   2, 3, 4  G077158E35562N  ...
# 325              Dasht  GL071728E37219N   2, 3, 4  G071729E37220N  ...
# 610            Unnamed  GL089248E27837N   2, 3, 4  G089264E27828N  ...
# 48              Barun   GL087138E27812N      2, 3  G087145E27832N  ...
#
#      Commerical_damaged                                            Infra  \
# 131                 NaN                                              NaN
# ...
