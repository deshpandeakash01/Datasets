# %%
# %pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gp

# %%
file_path=r'D:\Datasets\seismic-zone-1\data\GL_3basins_2015.shp'

# %%
data=gp.read_file(file_path)

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 3624 entries, 0 to 3623
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         3624 non-null   int64
#  1   Latitude   3624 non-null   float64
#  2   Longitude  3624 non-null   float64
#  3   GL_ID      3624 non-null   object
#  4   Basin      3624 non-null   object
#  5   Sub_Basin  3624 non-null   object
#  6   Area       3624 non-null   float64
#  7   Elevation  3624 non-null   int64
#  8   Type       3624 non-null   object
#  9   Country    3624 non-null   object
#  10  geometry   3624 non-null   geometry
# dtypes: float64(3), geometry(1), int64(2), object(5)
# memory usage: 311.6+ KB

# %%
data['geometry']
# Out:
# 0       POLYGON ((86.5069 28.88361, 86.50682 28.88362,...
# 1       POLYGON ((86.52124 28.84937, 86.52098 28.85014...
# 2       POLYGON ((87.48985 28.84717, 87.48986 28.84721...
# 3       POLYGON ((86.51435 28.84026, 86.51479 28.84097...
# 4       POLYGON ((87.49098 28.83993, 87.49108 28.84005...
#                               ...
# 3619    POLYGON ((83.7194 29.22824, 83.71925 29.22822,...
# 3620    POLYGON ((83.7947 29.23977, 83.79461 29.23977,...
# 3621    POLYGON ((83.79732 29.24431, 83.79722 29.2443,...
# 3622    POLYGON ((83.79577 29.24592, 83.79562 29.24591...
# 3623    POLYGON ((83.86264 29.29973, 83.86246 29.29972...
# Name: geometry, Length: 3624, dtype: geometry

# %%
# %pip install folium mapclassify
# Out:
# ...
#
#    ------------- -------------------------- 1/3 [mapclassify]
#    ------------- -------------------------- 1/3 [mapclassify]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    ---------------------------------------- 3/3 [folium]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Generate the map and assign it to a variable
map_view = data.explore()

# Save the map as a standalone webpage
map_view.save("basin_map.html")
